# %%
import numpy as np
import os,subprocess,sys
# %matplotlib notebook
# %matplotlib widget
import matplotlib.pyplot as plt


plt.rcParams['font.size']=16
plt.rcParams['font.family']='dejavu sans'

plt.rcParams['mathtext.fontset']='stix'
plt.rcParams['mathtext.rm']='custom'
plt.rcParams['mathtext.it']='stix:italic'
plt.rcParams['mathtext.bf']='stix:bold'

# %%
# %%sh
# make
# Out:
# make: Nothing to be done for 'all'.

# %%
_cpp=subprocess.check_output(["./spline_example.run"]).decode(sys.stdout.encoding)

# %%
T=[]
h_tab=[]
g_tab=[]

T_int=[]
h_0=[]
h_1=[]
h_3=[]
g_0=[]
g_1=[]
g_3=[]
dh_0=[]
dh_1=[]
dh_3=[]

i=1
for _ in _cpp.split("\n")[:]:
    try:
        if _=="data":
            break
    except:
        pass

    i+=1
    tmp=_.split(',')
    T.append(float(tmp[0]))
    h_tab.append(float(tmp[1]))
    g_tab.append(float(tmp[2]))

for _ in _cpp.split("\n")[i+1:]:
    try:
        if _=="end":
            break
    except:
        pass

    tmp=_.split(',')
    T_int.append(float(tmp[0]))
    h_0.append(float(tmp[1]))
    h_1.append(float(tmp[2]))
    h_3.append(float(tmp[3]))
    g_0.append(float(tmp[4]))
    g_1.append(float(tmp[5]))
    g_3.append(float(tmp[6]))
    dh_0.append(float(tmp[7]))
    dh_1.append(float(tmp[8]))
    dh_3.append(float(tmp[9]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3b65dc0accac> in <module>
#      25     tmp=_.split(',')
#      26     T.append(float(tmp[0]))
# ---> 27     h.append(float(tmp[1]))
#      28     g.append(float(tmp[2]))
#      29
#
# NameError: name 'h' is not defined

# %%
fig=plt.figure(figsize=(9,5))
fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.0,hspace=0.0)

sub = fig.add_subplot(1,1,1)


sub.plot(X_int,Y_0,linestyle='--',linewidth=1,alpha=1,c='xkcd:blue',label='interpolation-0')

sub.plot(X_int,Y_1,linestyle=':',linewidth=1.5,alpha=1,c='xkcd:black',label='interpolation-1')

sub.plot(X_int,Y_3,linestyle='-',linewidth=2,alpha=1,c='xkcd:red',label='interpolation-3')

sub.scatter(X,Y,alpha=1,c='xkcd:gray',marker='+',label='data')


sub.legend(bbox_to_anchor=(0.01, 0.99),borderaxespad=0., columnspacing=1,labelspacing=-0.1,
           borderpad=0,ncol=1,loc='upper left' ,framealpha=0)



sub.set_xlabel(r'$x$')
sub.xaxis.set_label_coords(0.5, -0.075) 
sub.set_ylabel(r'$sin(x)$')
sub.yaxis.set_label_coords(-0.07,0.5) 


fig.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig=plt.figure(figsize=(9,5))
fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.0,hspace=0.0)

sub = fig.add_subplot(1,1,1)


sub.plot(X_int,Yp_0,linestyle='--',linewidth=1,alpha=1,c='xkcd:blue',label='interpolation-0')

sub.plot(X_int,Yp_1,linestyle=':',linewidth=1.5,alpha=1,c='xkcd:black',label='interpolation-1')

sub.plot(X_int,Yp_3,linestyle='-',linewidth=2,alpha=1,c='xkcd:red',label='interpolation-3')

sub.scatter(X,Yp,alpha=1,c='xkcd:gray',marker='+',label='data')



sub.legend(bbox_to_anchor=(0.01, 0.99),borderaxespad=0., columnspacing=1,labelspacing=-0.1,
           borderpad=0,ncol=1,loc='upper left' ,framealpha=0)



sub.set_xlabel(r'$x$')
sub.xaxis.set_label_coords(0.5, -0.075) 
sub.set_ylabel(r'$sin^{\prime}(x)=cos(x)$')
sub.yaxis.set_label_coords(-0.07,0.5) 


fig.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig=plt.figure(figsize=(9,5))
fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.0,hspace=0.0)

sub = fig.add_subplot(1,1,1)


sub.plot(X_int,Ypp_0,linestyle='-',linewidth=1,alpha=1,c='xkcd:blue',label='interpolation-0')

sub.plot(X_int,Ypp_1,linestyle=':',linewidth=1.5,alpha=1,c='xkcd:black',label='interpolation-1')

sub.plot(X_int,Ypp_3,linestyle='-',linewidth=2,alpha=1,c='xkcd:red',label='interpolation-3')

sub.scatter(X,Ypp,alpha=1,c='xkcd:gray',marker='+',label='data')



sub.legend(bbox_to_anchor=(0.01, 0.99),borderaxespad=0., columnspacing=1,labelspacing=-0.1,
           borderpad=0,ncol=1,loc='upper left' ,framealpha=0)



sub.set_xlabel(r'$x$')
sub.xaxis.set_label_coords(0.5, -0.075) 
sub.set_ylabel(r'$sin^{\prime\prime}(x)=-sin(x)$')
sub.yaxis.set_label_coords(-0.07,0.5) 


fig.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
